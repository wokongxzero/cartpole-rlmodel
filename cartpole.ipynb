# %%
# %pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (1.6.2)
# Requirement already satisfied: importlib-metadata~=4.13 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: numpy in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (1.23.4)
# Requirement already satisfied: cloudpickle in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: torch>=1.11 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (1.12.1)
# Requirement already satisfied: gym==0.21 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: matplotlib in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (3.6.1)
# Requirement already satisfied: pandas in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (1.5.0)
# Requirement already satisfied: opencv-python in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (4.6.0.66)
# Requirement already satisfied: tqdm in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (4.64.1)
# Requirement already satisfied: ale-py==0.7.4 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (2.10.1)
# Requirement already satisfied: rich in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (12.6.0)
# Requirement already satisfied: psutil in c:\users\harna\appdata\roaming\python\python310\site-packages (from stable-baselines3[extra]) (5.9.2)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: pillow in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]) (9.2.0)
# Requirement already satisfied: importlib-resources in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.10.0)
# Requirement already satisfied: click in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.1.3)
# Requirement already satisfied: requests in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.28.1)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.9.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (58.1.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.49.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.19.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: wheel>=0.26 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.12.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: typing-extensions in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\harna\appdata\roaming\python\python310\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harna\appdata\roaming\python\python310\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\harna\appdata\roaming\python\python310\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.37.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from pandas->stable-baselines3[extra]) (2022.4)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\harna\appdata\roaming\python\python310\site-packages (from rich->stable-baselines3[extra]) (2.13.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from rich->stable-baselines3[extra]) (0.9.1)
# Requirement already satisfied: colorama in c:\users\harna\appdata\roaming\python\python310\site-packages (from tqdm->stable-baselines3[extra]) (0.4.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: six>=1.9.0 in c:\users\harna\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\harna\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the 'c:\Users\harna\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = "CartPole-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:20.0
# Episode:2 Score:12.0
# Episode:3 Score:32.0
# Episode:4 Score:14.0
# Episode:5 Score:25.0

# %%
env.close()

# %%
#understanding the environment
# 0-push cart to left, 1-push cart to the right
env.action_space.sample()
# Out:
# 1

# %%
# [cart position, cart velocity, pole angle, pole angular velocity]
env.observation_space.sample()
# Out:
# array([-2.8818517e+00,  8.5390506e+37, -8.8730782e-02, -1.8720668e+38],
#       dtype=float32)

# %%
#train an rl model
import os

log_path = os.path.join('train','logs')

# %%
log_path
# Out:
# 'train\\logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to train\logs\PPO_13
# -----------------------------
# | time/              |      |
# |    fps             | 1058 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 804         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008961154 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00143    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.77        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 55.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 740          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0088326335 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.664       |
# |    explained_variance   | 0.0779       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.3         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0156      |
# |    value_loss           | 42.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008743182 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 56.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 691          |
# |    iterations           | 5            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0077489177 |
# |    clip_fraction        | 0.0917       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.606       |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.7         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.02        |
# |    value_loss           | 61.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 652         |
# |    iterations           | 6           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010754268 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 60.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 649          |
# |    iterations           | 7            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0076426137 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.578       |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.4         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00877     |
# |    value_loss           | 41.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 649          |
# |    iterations           | 8            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0070492355 |
# |    clip_fraction        | 0.0835       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.577       |
# |    explained_variance   | 0.872        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.17         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0156      |
# |    value_loss           | 24.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 641          |
# |    iterations           | 9            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0059420103 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.23         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 40.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 645         |
# |    iterations           | 10          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008234731 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0.0742      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 26.2        |
# -----------------------------------------

# %%
import os 
PPO_path = os.path.join('Train', 'Saved Models', 'PPO_cartpole_model')

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load(PPO_path,env=env)

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# c:\Users\harna\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %%
obs = env.reset()

# %%
action,_ = model.predict(obs)

# %%
action
# Out:
# array([0], dtype=int64)

# %%
#testing and evaluation
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0


    while not done:
        env.render()
        action,_ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} score:{}'.format(episode,score))


env.close()
# Out:
# Episode:1 score:[200.]
# Episode:2 score:[200.]
# Episode:3 score:[200.]
# Episode:4 score:[200.]
# Episode:5 score:[200.]

# %%
model.predict(obs)
# Out:
# (array([0], dtype=int64), None)

# %%
import tensorboard
import tensorflow

# %%
training_log_path = os.path.join(log_path,'PPO_9')

# %%
training_log_path
# Out:
# 'train\\logs\\PPO_9'

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import  tensorflow as tf
import datetime

# %%
# %tensorboard --logdir="/Users/harna/Desktop/code/reinforced learning models/train/logs/PPO_9" --port=6006
# Out:
# Reusing TensorBoard on port 6006 (pid 20260), started 2:54:31 ago. (Use '!kill 20260' to kill it.)
#       <iframe id="tensorboard-frame-4d2d170fc1337da6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4d2d170fc1337da6");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
#ADDING A CALL BACK TO THE TRAINING STAGE
#SETTING REARD THRESHOLD
from stable_baselines3.common.callbacks import EvalCallback,StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('train','saved models')

# %%
from tabnanny import verbose


stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose =1)
eval_callback = EvalCallback(env,
                            callback_on_new_best = stop_callback,
                            eval_freq = 10000,
                            best_model_save_path=save_path,
                            verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# Logging to train\logs\PPO_14
# -----------------------------
# | time/              |      |
# |    fps             | 1020 |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 746          |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0090633705 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.00527      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.16         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0145      |
# |    value_loss           | 46.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009790704 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 33.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 4           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007141998 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 53          |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=183.00 +/- 21.85
# Episode length: 183.00 +/- 21.85
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 183         |
# |    mean_reward          | 183         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.008757178 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 57.3        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 633   |
# |    iterations      | 5     |
# |    time_elapsed    | 16    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 6           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007886303 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.4        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 54.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 7           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008062765 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 56.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 8            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0060550896 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.562       |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.2         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00968     |
# |    value_loss           | 46           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 9           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008256057 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 36          |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0025523587 |
# |    clip_fraction        | 0.00601      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | 0.3          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.42         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 33.5         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %%
#changing policies
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to train\logs\PPO_15
# -----------------------------
# | time/              |      |
# |    fps             | 669  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013747925 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.00428    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.72        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 20.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017352019 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 32.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009882396 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 49.6        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0075598303 |
# |    clip_fraction        | 0.0873       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.576       |
# |    explained_variance   | 0.447        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.2         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0149      |
# |    value_loss           | 45.1         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 413   |
# |    iterations      | 5     |
# |    time_elapsed    | 24    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 6           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007878396 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.13        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 29.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 7           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007959239 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 14.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 8           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004897821 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.401       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 5.7         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 9           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005616083 |
# |    clip_fraction        | 0.0733      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.527      |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.821       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 3.74        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0030771054 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | 0.687        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.263        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 2.67         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             |